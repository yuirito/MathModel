# %%
import pandas as pd
d=pd.read_excel(io='./p2data_zscore.xlsx')

# %%
d
# Out:
#           V1  SO2   NO2  PM10  PM2.5    O3   CO     T     H       P  ...  \
# 0          0  5.0  75.0  61.0   38.0   1.0  1.0  21.1  89.0  1013.0  ...
# 1          1  5.0  64.0  60.0   41.0  25.0  0.8  20.4  92.0  1012.4  ...
# 2          2  4.0  60.0  36.0   40.0  25.0  0.8  20.0  93.0  1011.3  ...
# 3          3  4.0  39.0  35.0   33.0  41.0  0.7  19.8  93.0  1010.4  ...
# 4          4  4.0  39.0  28.0   39.0  36.0  0.8  19.9  92.0  1010.0  ...
# ...      ...  ...   ...   ...    ...   ...  ...   ...   ...     ...  ...
# 19427  19427  6.0  12.0  12.0    0.0  14.0  0.4  29.2  78.0  1006.2  ...
# 19428  19428  7.0  15.0   9.0    0.0  11.0  0.4  29.2  78.0  1006.3  ...
# 19429  19429  9.0  19.0   9.0    2.0   8.0  0.4  29.2  78.0  1006.4  ...
# 19430  19430  8.0  20.0  22.0    5.0   6.0  0.4  29.0  81.0  1006.8  ...
# 19431  19431  8.0  14.0  22.0    5.0  19.0  0.4  30.2  75.0  1007.0  ...
#
#        MainP  class  NO2Class  O3Class PM10Class        ZT        ZH  \
# ...

# %%
PM10_1=[-0.242,0.766,0.589,0.627,0]
PM10_2=[1.131,-0.062,0.716,0.461,-0.444]

# %%
x=[-0.682798,1.223091,0.372831,-0.269612,1.630232]

# %%
import numpy as np
PM10_1=np.array([-0.242,0.766,0.589,0.627,0])
PM10_2=np.array([1.131,-0.062,0.716,0.461,-0.444])
x=np.array([-0.682798,1.223091,0.372831,-0.269612,1.630232])
y=(PM10_1*x)

# %%
y
# Out:
# array([ 0.16523712,  0.93688771,  0.21959746, -0.16904672,  0.        ])

# %%
sum(y)
# Out:
# 1.152675557

# %%
sum(PM10_2*x)
# Out:
# -1.4292433240000002
